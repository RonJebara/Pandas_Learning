# %%
import numpy as np
import pandas as pd
import glob

# %% [markdown]
# # Reading from file

# %%
coffee = pd.read_csv('coffee.csv')
# df = pd.read_parquet("filename.pqt")

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
all_files = glob.glob("*.parquet")
for filename in all_files:
  results = pd.read_parquet(filename)
bios = pd.read_csv("bios.csv")

# %% [markdown]
# # Accessing Data

# %%
coffee
#print(coffee) does the same
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.tail()
# Out:
#          Day Coffee Type  Units Sold
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
coffee.sample(3, random_state=1)
#random state makes the sample deterministic. Will return the same results
# Out:
#         Day Coffee Type  Units Sold
# 3   Tuesday       Latte          20
# 7  Thursday       Latte          30
# 6  Thursday    Espresso          40

# %%
# loc allows you to filter rows and columns of a df

coffee.loc[5:7, ["Day", "Units Sold"]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 6   Thursday          40
# 7   Thursday          30

# %%
# iloc is similar but uses index numbers instead of names

coffee.iloc[:, [0, 2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
#coffee.index = coffee["Day"]
#coffee.loc["Monday":"Wednesday", ["Units Sold"]]

# %%
#coffee.loc[1:3, "Units Sold"] = 10
#coffee.head()

# %%
#at to grab one specific piece of data

coffee.at[0,"Day"]
# Out:
# 'Monday'

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[1, 0])
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index, row in coffee.iterrows():
  print(index, row["Day"], row["Units Sold"])
# Out:
# 0 Monday 25
# 1 Monday 15
# 2 Tuesday 30
# 3 Tuesday 20
# 4 Wednesday 35
# 5 Wednesday 25
# 6 Thursday 40
# 7 Thursday 30
# 8 Friday 45
# 9 Friday 35
# 10 Saturday 45
# 11 Saturday 35
# 12 Sunday 45
# 13 Sunday 35

# %%
coffee.loc[:, ['Day', 'Units Sold']]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %% [markdown]
# # Filtering Data

# %%
bios.loc[bios['height_cm'] > 220, ['name', 'height_cm']]
# Out:
#                    name  height_cm
# 5673     Gunther Behnke      221.0
# 5781     Tommy Burleson      223.0
# 6978    Arvydas Sabonis      223.0
# 89070          Yao Ming      226.0
# 89075    Roberto Dueñas      221.0
# 120266     Zhang Zhaoxu      221.0

# %%
bios[(bios['height_cm'] > 210) & (bios['born_country'] == 'USA')][['name', 'height_cm']]
# Out:
#                       name  height_cm
# 5681          Walt Bellamy      211.0
# 5781        Tommy Burleson      223.0
# 5894            Mel Counts      213.0
# 6106       Marc Freiberger      211.0
# 6281        Darrall Imhoff      211.0
# 6379            Joe Kleine      211.0
# 6393            Jon Koncak      213.0
# 6442    Christian Laettner      211.0
# 6615          Tom McMillen      212.0
# 6722      Shaquille O'Neal      216.0
# 6937        David Robinson      216.0
# 7012       Daniel Santiago      213.0
# 112319         Chris Kaman      213.0
# 112366       Dwight Howard      211.0
# 118573     Al-Farouq Aminu      211.0
# 123850      Tyson Chandler      216.0
# 132188    Domantas Sabonis      211.0
# 133332      DeAndre Jordan      211.0
# 142044       Jahlil Okafor      211.0
# 142930          Mike Tobey      213.0
# 143712        JaVale McGee      213.0

# %%
bios[bios['name'].str.contains("ronnie|Taylor")].sort_values('born_date', ascending = False)
# Out:
#         athlete_id                name   born_date   born_city  \
# 136263      139487       Jessie Taylor  2004-05-17         NaN
# 127090      129515         Taylor Ruck  2000-05-28     Kelowna
# 140739      144258  Christopher Taylor  1999-10-01         NaN
# 143478      147130       Taylor Manson  1999-09-29         NaN
# 143636      147290        Taylor Knibb  1998-02-14         NaN
# ...            ...                 ...         ...         ...
# 63398        63874       Howard Taylor  1861-06-30     Peckham
# 18084        18205    Frederick Taylor  1856-03-20  Germantown
# 2237          2247        Homer Taylor  1851-08-19      Leyden
# 29951        30177        H. W. Taylor         NaN         NaN
# 36774        37068           Peyronnie         NaN         NaN
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 136263               NaN          NaN  Great Britain        NaN        NaN
# ...

# %%
bios[bios['born_country'].isin(['USA', 'FRA', "GBR"]) * bios['name'].str.contains("Ronnie")]
# Out:
#         athlete_id              name   born_date     born_city   born_region  \
# 3485          3497      Ronnie Smith  1944-10-15     Liverpool       England
# 8640          8687     Ronnie Harris  1947-02-08       Detroit      Michigan
# 8641          8688     Ronnie Harris  1948-09-03        Canton          Ohio
# 25091        25281    Ronnie Simpson  1930-10-11       Glasgow      Scotland
# 46870        47219      Ronnie Burns  1933-04-10         Perth      Scotland
# 51132        51491      Ronnie Mills  1951-02-25    Fort Worth         Texas
# 78471        79062  Ronnie Ray Smith  1949-03-28   Los Angeles    California
# 87142        87838   Ronnie Kauffman  1946-12-25       Seattle    Washington
# 96121        96896  Ronnie Robertson  1937-09-25  Brackenridge  Pennsylvania
# 133323      136262        Ronnie Ash  1988-07-02       Passaic    New Jersey
#
#        born_country            NOC  height_cm  weight_kg   died_date
# ...

# %%
bios.query('born_country == "USA" and born_city == "Seattle"')
# Out:
#         athlete_id                   name   born_date born_city born_region  \
# 11030        11088          David Halpern  1955-08-18   Seattle  Washington
# 12800        12870            Todd Trewin  1958-04-20   Seattle  Washington
# 15476        15583         Scott McKinley  1968-10-15   Seattle  Washington
# 29079        29293            Joyce Tanac  1950-09-27   Seattle  Washington
# 31135        31371        Bill Kuhlemeier  1908-01-14   Seattle  Washington
# ...            ...                    ...         ...       ...         ...
# 133392      136331          Hans Struzyna  1989-03-31   Seattle  Washington
# 135448      138662  Maude Davis Crossland  2003-03-19   Seattle  Washington
# 136993      140229        Jenell Berhorst  2003-12-13   Seattle  Washington
# 143507      147159         Nevin Harrison  2002-06-02   Seattle  Washington
# 145446      149169       Corinne Stoddard  2001-08-15   Seattle  Washington
#
# ...

# %% [markdown]
# # Adding / Removing Columns

# %%
coffee['price'] = 4.99
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 5.99, 3.99)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   4.99       5.99
# 1      Monday       Latte          15   4.99       3.99
# 2     Tuesday    Espresso          30   4.99       5.99
# 3     Tuesday       Latte          20   4.99       3.99
# 4   Wednesday    Espresso          35   4.99       5.99
# 5   Wednesday       Latte          25   4.99       3.99
# 6    Thursday    Espresso          40   4.99       5.99
# 7    Thursday       Latte          30   4.99       3.99
# 8      Friday    Espresso          45   4.99       5.99
# 9      Friday       Latte          35   4.99       3.99
# 10   Saturday    Espresso          45   4.99       5.99
# 11   Saturday       Latte          35   4.99       3.99
# 12     Sunday    Espresso          45   4.99       5.99
# 13     Sunday       Latte          35   4.99       3.99

# %%
coffee = coffee.drop(columns=['price'])
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       5.99
# 1      Monday       Latte          15       3.99
# 2     Tuesday    Espresso          30       5.99
# 3     Tuesday       Latte          20       3.99
# 4   Wednesday    Espresso          35       5.99
# 5   Wednesday       Latte          25       3.99
# 6    Thursday    Espresso          40       5.99
# 7    Thursday       Latte          30       3.99
# 8      Friday    Espresso          45       5.99
# 9      Friday       Latte          35       3.99
# 10   Saturday    Espresso          45       5.99
# 11   Saturday       Latte          35       3.99
# 12     Sunday    Espresso          45       5.99
# 13     Sunday       Latte          35       3.99

# %%
# df2 = df makes a pointer
# need to do df2 = df.copy

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-221-661775382.py in <cell line: 0>()
#       1 coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']
# ----> 2 coffee.drop(columns=['price'], inplace=True)
#       3 coffee
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
coffee.rename(columns = {'new_price' : 'price'}, inplace=True)
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   5.99   149.75
# 1      Monday       Latte          15   3.99    59.85
# 2     Tuesday    Espresso          30   5.99   179.70
# 3     Tuesday       Latte          20   3.99    79.80
# 4   Wednesday    Espresso          35   5.99   209.65
# 5   Wednesday       Latte          25   3.99    99.75
# 6    Thursday    Espresso          40   5.99   239.60
# 7    Thursday       Latte          30   3.99   119.70
# 8      Friday    Espresso          45   5.99   269.55
# 9      Friday       Latte          35   3.99   139.65
# 10   Saturday    Espresso          45   5.99   269.55
# 11   Saturday       Latte          35   3.99   139.65
# 12     Sunday    Espresso          45   5.99   269.55
# 13     Sunday       Latte          35   3.99   139.65
