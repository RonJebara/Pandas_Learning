# %% [markdown]
# <a href="https://colab.research.google.com/github/RonJebara/Pandas_Learning/blob/main/Pandas_DataFrame_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import pandas as pd

df = pd.DataFrame([[1,2,3], [4,5,6], [7,8,9], [1,2,3], [1,2,3], [1,2,3]], columns = ["A", "B", "C"], index = ["x", 'y', 'z', 'a', 'b', 'c'])

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9
# a  1  2  3
# b  1  2  3

# %%
df.head(1)
# Out:
#    A  B  C
# x  1  2  3

# %%
df.tail(2)
# Out:
#    A  B  C
# b  1  2  3
# c  1  2  3

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z', 'a', 'b', 'c']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, x to c
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      int64
#  1   B       6 non-null      int64
#  2   C       6 non-null      int64
# dtypes: int64(3)
# memory usage: 364.0+ bytes

# %%
df.describe()
# Out:
#              A        B        C
# count  6.00000  6.00000  6.00000
# mean   2.50000  3.50000  4.50000
# std    2.50998  2.50998  2.50998
# min    1.00000  2.00000  3.00000
# 25%    1.00000  2.00000  3.00000
# 50%    1.00000  2.00000  3.00000
# 75%    3.25000  4.25000  5.25000
# max    7.00000  8.00000  9.00000

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (6, 3)
